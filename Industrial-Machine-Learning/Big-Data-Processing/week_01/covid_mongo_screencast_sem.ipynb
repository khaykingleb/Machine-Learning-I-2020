# %% [markdown]
# # Covid Database
#
# В предложенной базе собраны записи о заболевании в различных странах мира.
# Для каждой страны представленны записи по нескольким дням наблюдения. В некоторых странах существует сразу несколько регионов, в которых производили замеры.

# %%
from pymongo import MongoClient
import json

# %%
client = MongoClient('localhost', 27017)
# коллекция world внутри базы covid
world = client.covid.world

# %%
from pprint import pprint

# функция, чтобы красиво печатать результаты
def p(x):
    pprint(list(x))

# %% [markdown]
# #### MongoDB Find

# %%
# посмотрим на 10 записей в коллекции

"""
SELECT *
FROM world
LIMIT 10
"""

p(world.find({}).limit(10))
# Out:
# [{'_id': ObjectId('5f09dd02e7b6b3d98579951b'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 0,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 1, 23, 0, 0),
#   'deaths': 0,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 0,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579951c'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 0,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 1, 24, 0, 0),
#   'deaths': 0,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 0,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d985799521'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 0,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 1, 29, 0, 0),
#   'deaths': 0,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 0,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d985799526'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 0,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 2, 3, 0, 0),
#   'deaths': 0,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 0,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d985799529'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 0,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 2, 6, 0, 0),
#   'deaths': 0,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 0,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579952a'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 0,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 2, 7, 0, 0),
#   'deaths': 0,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 0,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579952b'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 0,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 2, 8, 0, 0),
#   'deaths': 0,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 0,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579952c'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 0,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 2, 9, 0, 0),
#   'deaths': 0,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 0,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579952d'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 0,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 2, 10, 0, 0),
#   'deaths': 0,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 0,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579952f'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 0,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 2, 12, 0, 0),
#   'deaths': 0,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 0,
#   'uid': 4}]

# %%
# чтобы узнать количество записей в запросе можно воспользоваться функцией count:

"""
SELECT count(*)
FROM world
"""

world.find({}).count()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
# 45657

# %%
# посмотрим на все регионы Франции, где фискировали статистику
# для этого используем функцию distinct

"""
SELECT distinct combined_name
FROM world
WHERE country = 'France'
"""

p(world.find({"country": "France"}).distinct("combined_name"))
# Out:
# ['France',
#  'French Guiana, France',
#  'French Polynesia, France',
#  'Guadeloupe, France',
#  'Martinique, France',
#  'Mayotte, France',
#  'New Caledonia, France',
#  'Reunion, France',
#  'Saint Barthelemy, France',
#  'Saint Pierre and Miquelon, France',
#  'St Martin, France']

# %%
# мы можем указать конкретные поля, которые хотим получить из базы
# например, хотим только название страны, количество умерших и дату

"""
SELECT country, deaths, date
FROM world
WHERE country = 'France'
LIMIT 10
"""

p(world.find({"country": "France"},
             {"country": 1, "deaths": 1, "date": 1}).limit(10))
# Out:
# [{'_id': ObjectId('5f09dd02e7b6b3d98579ddc6'),
#   'country': 'France',
#   'date': datetime.datetime(2020, 6, 6, 0, 0),
#   'deaths': 0},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ddc7'),
#   'country': 'France',
#   'date': datetime.datetime(2020, 6, 7, 0, 0),
#   'deaths': 0},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ddc8'),
#   'country': 'France',
#   'date': datetime.datetime(2020, 6, 8, 0, 0),
#   'deaths': 0},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ddc9'),
#   'country': 'France',
#   'date': datetime.datetime(2020, 6, 9, 0, 0),
#   'deaths': 0},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ddca'),
#   'country': 'France',
#   'date': datetime.datetime(2020, 6, 10, 0, 0),
#   'deaths': 0},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ddcb'),
#   'country': 'France',
#   'date': datetime.datetime(2020, 6, 11, 0, 0),
#   'deaths': 0},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ddcc'),
#   'country': 'France',
#   'date': datetime.datetime(2020, 6, 12, 0, 0),
#   'deaths': 0},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ddcd'),
#   'country': 'France',
#   'date': datetime.datetime(2020, 6, 13, 0, 0),
#   'deaths': 0},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ddce'),
#   'country': 'France',
#   'date': datetime.datetime(2020, 6, 14, 0, 0),
#   'deaths': 0},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ddcf'),
#   'country': 'France',
#   'date': datetime.datetime(2020, 6, 15, 0, 0),
#   'deaths': 0}]

# %%
# в запросе можно использовать более сложные логические конструкции,
# каждая из них реализуется отдельным оператором

"""
SELECT *
FROM world
WHERE
    country in ('United Kingdom', 'Ireland')
    and deaths > 3
    and recovered <> 0
LIMIT 10
"""

p(world.find({"country": {"$in": ["United Kingdom", "Ireland"]},
              "deaths": {"$gt": 3},  # gt = greater than 
              "recovered": {"$ne": 0}}).limit(10))
# Out:
# [{'_id': ObjectId('5f09dd02e7b6b3d98579ef83'),
#   'combined_name': 'Ireland',
#   'confirmed': 906,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 22, 0, 0),
#   'deaths': 4,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef84'),
#   'combined_name': 'Ireland',
#   'confirmed': 1125,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 23, 0, 0),
#   'deaths': 6,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef85'),
#   'combined_name': 'Ireland',
#   'confirmed': 1329,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 24, 0, 0),
#   'deaths': 7,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef86'),
#   'combined_name': 'Ireland',
#   'confirmed': 1564,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 25, 0, 0),
#   'deaths': 9,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef87'),
#   'combined_name': 'Ireland',
#   'confirmed': 1819,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 26, 0, 0),
#   'deaths': 19,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef88'),
#   'combined_name': 'Ireland',
#   'confirmed': 2121,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 27, 0, 0),
#   'deaths': 22,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef89'),
#   'combined_name': 'Ireland',
#   'confirmed': 2415,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 28, 0, 0),
#   'deaths': 36,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef8a'),
#   'combined_name': 'Ireland',
#   'confirmed': 2615,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 29, 0, 0),
#   'deaths': 46,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef8b'),
#   'combined_name': 'Ireland',
#   'confirmed': 2910,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 30, 0, 0),
#   'deaths': 54,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef8c'),
#   'combined_name': 'Ireland',
#   'confirmed': 3235,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 31, 0, 0),
#   'deaths': 71,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372}]

# %%
# можно использовать логические операторы для выставления более сложного запроса:

"""
SELECT *
FROM world
WHERE
    country in ('United Kingdom', 'Ireland')
    and deaths > 3
    and recovered <> 0
    and (confirmed < 5 or confirmed > 10)
LIMIT 10
"""

p(world.find({"$and": [{"country": {"$in": ["United Kingdom", "Ireland"]}}, # Связываем условия логическим И
                       {"deaths": {"$gt": 3}},
                       {"recovered": {"$ne": 0}},
                       {"$or": [{'confirmed': {"$lte": 5}}, # Связываем условия логическим ИЛИ
                                {'confirmed': {"$gte": 10}}]}
                      ]
             }).limit(10))
# Out:
# [{'_id': ObjectId('5f09dd02e7b6b3d98579ef83'),
#   'combined_name': 'Ireland',
#   'confirmed': 906,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 22, 0, 0),
#   'deaths': 4,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef84'),
#   'combined_name': 'Ireland',
#   'confirmed': 1125,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 23, 0, 0),
#   'deaths': 6,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef85'),
#   'combined_name': 'Ireland',
#   'confirmed': 1329,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 24, 0, 0),
#   'deaths': 7,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef86'),
#   'combined_name': 'Ireland',
#   'confirmed': 1564,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 25, 0, 0),
#   'deaths': 9,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef87'),
#   'combined_name': 'Ireland',
#   'confirmed': 1819,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 26, 0, 0),
#   'deaths': 19,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef88'),
#   'combined_name': 'Ireland',
#   'confirmed': 2121,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 27, 0, 0),
#   'deaths': 22,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef89'),
#   'combined_name': 'Ireland',
#   'confirmed': 2415,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 28, 0, 0),
#   'deaths': 36,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef8a'),
#   'combined_name': 'Ireland',
#   'confirmed': 2615,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 29, 0, 0),
#   'deaths': 46,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef8b'),
#   'combined_name': 'Ireland',
#   'confirmed': 2910,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 30, 0, 0),
#   'deaths': 54,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579ef8c'),
#   'combined_name': 'Ireland',
#   'confirmed': 3235,
#   'country': 'Ireland',
#   'country_code': 372,
#   'country_iso2': 'IE',
#   'country_iso3': 'IRL',
#   'date': datetime.datetime(2020, 3, 31, 0, 0),
#   'deaths': 71,
#   'loc': {'coordinates': [-7.6921, 53.1424], 'type': 'Point'},
#   'population': 4937796,
#   'recovered': 5,
#   'uid': 372}]

# %%
# для строк есть несколько дополнительных возможностей по поиску
# например, поиск по regex

"""
SELECT distinct country
FROM world
WHERE country similar to 'land$'
"""

p(world.find({"country": {"$regex": "land$"}}).distinct("country"))
# Out:
# ['Finland',
#  'Iceland',
#  'Ireland',
#  'New Zealand',
#  'Poland',
#  'Switzerland',
#  'Thailand']

# %%
# если стандартных операторов не хватает для задания необходимого условия, 
# можно использовать Javasctipt функцию в явном виде

p(world.find({"$where": """
                        function() 
                        {
                            if (this.recovered + this.deaths + this.confirmed > 5000) 
                            {
                                return true;
                            } else 
                            {
                                return false;
                            }
                        }
                        """}).limit(10))
# Out:
# [{'_id': ObjectId('5f09dd02e7b6b3d985799587'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 4402,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 5, 10, 0, 0),
#   'deaths': 120,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 558,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d985799588'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 4687,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 5, 11, 0, 0),
#   'deaths': 122,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 558,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d985799589'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 4963,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 5, 12, 0, 0),
#   'deaths': 127,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 610,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579958a'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 5226,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 5, 13, 0, 0),
#   'deaths': 132,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 648,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579958b'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 5639,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 5, 14, 0, 0),
#   'deaths': 136,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 691,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579958c'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 6053,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 5, 15, 0, 0),
#   'deaths': 153,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 745,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579958d'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 6402,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 5, 16, 0, 0),
#   'deaths': 168,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 745,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579958e'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 6664,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 5, 17, 0, 0),
#   'deaths': 169,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 778,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d98579958f'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 7072,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 5, 18, 0, 0),
#   'deaths': 173,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 801,
#   'uid': 4},
#  {'_id': ObjectId('5f09dd02e7b6b3d985799590'),
#   'combined_name': 'Afghanistan',
#   'confirmed': 7653,
#   'country': 'Afghanistan',
#   'country_code': 4,
#   'country_iso2': 'AF',
#   'country_iso3': 'AFG',
#   'date': datetime.datetime(2020, 5, 19, 0, 0),
#   'deaths': 178,
#   'loc': {'coordinates': [67.71, 33.9391], 'type': 'Point'},
#   'population': 38928341,
#   'recovered': 850,
#   'uid': 4}]

# %% [markdown]
# Более подробную информацию про составление поисковых запросов в MongoDB можно найти в официальной документации — https://docs.mongodb.com/manual/tutorial/query-documents/

# %%
# более сложные агрегации производятся с помощью агрегационного пайплайна
# это последовательность действий, которые необходимо применить к коллекции
# на каждом шаге используется свой отдельный оператор
# попробуем подсчитать, сколько записей с каждой страной

"""
SELECT count(1) as count, country
FROM world
GROUP BY country
"""
# group позволяет группировать данные
p(world.aggregate([{'$group': {"_id": {"country": "$country"}, # в _id записываются поля, по которым необходимо группировать
                               "count": {"$sum": 1}}}])) # далее записываются поля и агрегирующие операции
# здесь мы в count хотим подсчитать общее количество записей — суммируем количество единиц для каждой записи
# Out:
# [{'_id': {'country': 'Andorra'}, 'count': 171},
#  {'_id': {'country': 'Senegal'}, 'count': 171},
#  {'_id': {'country': 'Malaysia'}, 'count': 171},
#  {'_id': {'country': 'Sao Tome and Principe'}, 'count': 171},
#  {'_id': {'country': 'Bolivia'}, 'count': 171},
#  {'_id': {'country': 'Kuwait'}, 'count': 171},
#  {'_id': {'country': 'Norway'}, 'count': 171},
#  {'_id': {'country': 'Afghanistan'}, 'count': 171},
#  {'_id': {'country': 'Finland'}, 'count': 171},
#  {'_id': {'country': 'Lebanon'}, 'count': 171},
#  {'_id': {'country': 'San Marino'}, 'count': 171},
#  {'_id': {'country': 'Western Sahara'}, 'count': 171},
#  {'_id': {'country': 'Ethiopia'}, 'count': 171},
#  {'_id': {'country': 'Bosnia and Herzegovina'}, 'count': 171},
#  {'_id': {'country': 'Latvia'}, 'count': 171},
#  {'_id': {'country': 'Peru'}, 'count': 171},
#  {'_id': {'country': 'Saint Lucia'}, 'count': 171},
#  {'_id': {'country': 'Qatar'}, 'count': 171},
#  {'_id': {'country': 'China'}, 'count': 5643},
#  {'_id': {'country': 'Cameroon'}, 'count': 171},
#  {'_id': {'country': 'Colombia'}, 'count': 171},
#  {'_id': {'country': 'Singapore'}, 'count': 171},
#  {'_id': {'country': 'Lesotho'}, 'count': 171},
#  {'_id': {'country': 'Seychelles'}, 'count': 171},
#  {'_id': {'country': 'Antigua and Barbuda'}, 'count': 171},
#  {'_id': {'country': 'New Zealand'}, 'count': 171},
#  {'_id': {'country': 'Cabo Verde'}, 'count': 171},
#  {'_id': {'country': 'Tajikistan'}, 'count': 171},
#  {'_id': {'country': 'Papua New Guinea'}, 'count': 171},
#  {'_id': {'country': 'Nigeria'}, 'count': 171},
#  {'_id': {'country': 'Luxembourg'}, 'count': 171},
#  {'_id': {'country': 'Congo (Brazzaville)'}, 'count': 171},
#  {'_id': {'country': 'Algeria'}, 'count': 171},
#  {'_id': {'country': 'Chad'}, 'count': 171},
#  {'_id': {'country': 'Jamaica'}, 'count': 171},
#  {'_id': {'country': 'Montenegro'}, 'count': 171},
#  {'_id': {'country': 'Netherlands'}, 'count': 855},
#  {'_id': {'country': 'United Arab Emirates'}, 'count': 171},
#  {'_id': {'country': 'Syria'}, 'count': 171},
#  {'_id': {'country': 'Croatia'}, 'count': 171},
#  {'_id': {'country': 'Mauritius'}, 'count': 171},
#  {'_id': {'country': 'Tunisia'}, 'count': 171},
#  {'_id': {'country': 'Bulgaria'}, 'count': 171},
#  {'_id': {'country': 'Albania'}, 'count': 171},
#  {'_id': {'country': 'Uganda'}, 'count': 171},
#  {'_id': {'country': 'Eswatini'}, 'count': 171},
#  {'_id': {'country': 'Canada'}, 'count': 2565},
#  {'_id': {'country': 'South Sudan'}, 'count': 171},
#  {'_id': {'country': 'Guinea-Bissau'}, 'count': 171},
#  {'_id': {'country': 'Poland'}, 'count': 171},
#  {'_id': {'country': 'Sudan'}, 'count': 171},
#  {'_id': {'country': 'Saint Kitts and Nevis'}, 'count': 171},
#  {'_id': {'country': 'Zambia'}, 'count': 171},
#  {'_id': {'country': 'Cambodia'}, 'count': 171},
#  {'_id': {'country': 'Guinea'}, 'count': 171},
#  {'_id': {'country': 'Iceland'}, 'count': 171},
#  {'_id': {'country': 'Libya'}, 'count': 171},
#  {'_id': {'country': 'MS Zaandam'}, 'count': 171},
#  {'_id': {'country': 'Djibouti'}, 'count': 171},
#  {'_id': {'country': 'Serbia'}, 'count': 171},
#  {'_id': {'country': 'Comoros'}, 'count': 171},
#  {'_id': {'country': 'Iran'}, 'count': 171},
#  {'_id': {'country': 'Kenya'}, 'count': 171},
#  {'_id': {'country': 'Lithuania'}, 'count': 171},
#  {'_id': {'country': 'Denmark'}, 'count': 513},
#  {'_id': {'country': 'Monaco'}, 'count': 171},
#  {'_id': {'country': 'Korea, South'}, 'count': 171},
#  {'_id': {'country': 'Moldova'}, 'count': 171},
#  {'_id': {'country': 'Germany'}, 'count': 171},
#  {'_id': {'country': 'Holy See'}, 'count': 171},
#  {'_id': {'country': 'France'}, 'count': 1881},
#  {'_id': {'country': 'Philippines'}, 'count': 171},
#  {'_id': {'country': 'Czechia'}, 'count': 171},
#  {'_id': {'country': 'Estonia'}, 'count': 171},
#  {'_id': {'country': 'Mongolia'}, 'count': 171},
#  {'_id': {'country': 'South Africa'}, 'count': 171},
#  {'_id': {'country': 'Laos'}, 'count': 171},
#  {'_id': {'country': 'Egypt'}, 'count': 171},
#  {'_id': {'country': 'Saint Vincent and the Grenadines'}, 'count': 171},
#  {'_id': {'country': 'Yemen'}, 'count': 171},
#  {'_id': {'country': 'Namibia'}, 'count': 171},
#  {'_id': {'country': 'Gambia'}, 'count': 171},
#  {'_id': {'country': 'Maldives'}, 'count': 171},
#  {'_id': {'country': 'Somalia'}, 'count': 171},
#  {'_id': {'country': 'Haiti'}, 'count': 171},
#  {'_id': {'country': 'Honduras'}, 'count': 171},
#  {'_id': {'country': 'Pakistan'}, 'count': 171},
#  {'_id': {'country': 'Argentina'}, 'count': 171},
#  {'_id': {'country': 'Grenada'}, 'count': 171},
#  {'_id': {'country': 'Liechtenstein'}, 'count': 171},
#  {'_id': {'country': 'Morocco'}, 'count': 171},
#  {'_id': {'country': 'Malta'}, 'count': 171},
#  {'_id': {'country': 'Chile'}, 'count': 171},
#  {'_id': {'country': 'Angola'}, 'count': 171},
#  {'_id': {'country': 'Mauritania'}, 'count': 171},
#  {'_id': {'country': 'Armenia'}, 'count': 171},
#  {'_id': {'country': 'Eritrea'}, 'count': 171},
#  {'_id': {'country': 'Bahrain'}, 'count': 171},
#  {'_id': {'country': 'Austria'}, 'count': 171},
#  {'_id': {'country': 'Brunei'}, 'count': 171},
#  {'_id': {'country': 'Panama'}, 'count': 171},
#  {'_id': {'country': 'Rwanda'}, 'count': 171},
#  {'_id': {'country': 'Sri Lanka'}, 'count': 171},
#  {'_id': {'country': 'Belgium'}, 'count': 171},
#  {'_id': {'country': 'Indonesia'}, 'count': 171},
#  {'_id': {'country': 'Ecuador'}, 'count': 171},
#  {'_id': {'country': 'El Salvador'}, 'count': 171},
#  {'_id': {'country': 'North Macedonia'}, 'count': 171},
#  {'_id': {'country': 'Hungary'}, 'count': 171},
#  {'_id': {'country': 'Oman'}, 'count': 171},
#  {'_id': {'country': 'Russia'}, 'count': 171},
#  {'_id': {'country': 'Saudi Arabia'}, 'count': 171},
#  {'_id': {'country': 'Taiwan*'}, 'count': 171},
#  {'_id': {'country': 'Uruguay'}, 'count': 171},
#  {'_id': {'country': 'US'}, 'count': 171},
#  {'_id': {'country': 'Venezuela'}, 'count': 171},
#  {'_id': {'country': 'Burundi'}, 'count': 171},
#  {'_id': {'country': 'Kazakhstan'}, 'count': 171},
#  {'_id': {'country': 'Turkey'}, 'count': 171},
#  {'_id': {'country': 'Tanzania'}, 'count': 171},
#  {'_id': {'country': "Cote d'Ivoire"}, 'count': 171},
#  {'_id': {'country': 'Botswana'}, 'count': 171},
#  {'_id': {'country': 'Mexico'}, 'count': 171},
#  {'_id': {'country': 'Romania'}, 'count': 171},
#  {'_id': {'country': 'Burkina Faso'}, 'count': 171},
#  {'_id': {'country': 'West Bank and Gaza'}, 'count': 171},
#  {'_id': {'country': 'Diamond Princess'}, 'count': 171},
#  {'_id': {'country': 'Burma'}, 'count': 171},
#  {'_id': {'country': 'Uzbekistan'}, 'count': 171},
#  {'_id': {'country': 'Nicaragua'}, 'count': 171},
#  {'_id': {'country': 'Brazil'}, 'count': 171},
#  {'_id': {'country': 'Cuba'}, 'count': 171},
#  {'_id': {'country': 'Madagascar'}, 'count': 171},
#  {'_id': {'country': 'Benin'}, 'count': 171},
#  {'_id': {'country': 'United Kingdom'}, 'count': 1881},
#  {'_id': {'country': 'Vietnam'}, 'count': 171},
#  {'_id': {'country': 'Belarus'}, 'count': 171},
#  {'_id': {'country': 'Dominica'}, 'count': 171},
#  {'_id': {'country': 'Barbados'}, 'count': 171},
#  {'_id': {'country': 'Bhutan'}, 'count': 171},
#  {'_id': {'country': 'Dominican Republic'}, 'count': 171},
#  {'_id': {'country': 'Italy'}, 'count': 171},
#  {'_id': {'country': 'Mozambique'}, 'count': 171},
#  {'_id': {'country': 'Guatemala'}, 'count': 171},
#  {'_id': {'country': 'Iraq'}, 'count': 171},
#  {'_id': {'country': 'Suriname'}, 'count': 171},
#  {'_id': {'country': 'Thailand'}, 'count': 171},
#  {'_id': {'country': 'Sierra Leone'}, 'count': 171},
#  {'_id': {'country': 'Fiji'}, 'count': 171},
#  {'_id': {'country': 'Gabon'}, 'count': 171},
#  {'_id': {'country': 'Georgia'}, 'count': 171},
#  {'_id': {'country': 'Greece'}, 'count': 171},
#  {'_id': {'country': 'Ireland'}, 'count': 171},
#  {'_id': {'country': 'Japan'}, 'count': 171},
#  {'_id': {'country': 'Paraguay'}, 'count': 171},
#  {'_id': {'country': 'Spain'}, 'count': 171},
#  {'_id': {'country': 'Togo'}, 'count': 171},
#  {'_id': {'country': 'Congo (Kinshasa)'}, 'count': 171},
#  {'_id': {'country': 'Guyana'}, 'count': 171},
#  {'_id': {'country': 'Costa Rica'}, 'count': 171},
#  {'_id': {'country': 'Ghana'}, 'count': 171},
#  {'_id': {'country': 'Bangladesh'}, 'count': 171},
#  {'_id': {'country': 'Nepal'}, 'count': 171},
#  {'_id': {'country': 'Niger'}, 'count': 171},
#  {'_id': {'country': 'Slovenia'}, 'count': 171},
#  {'_id': {'country': 'Australia'}, 'count': 1368},
#  {'_id': {'country': 'Trinidad and Tobago'}, 'count': 171},
#  {'_id': {'country': 'Zimbabwe'}, 'count': 171},
#  {'_id': {'country': 'Timor-Leste'}, 'count': 171},
#  {'_id': {'country': 'Belize'}, 'count': 171},
#  {'_id': {'country': 'Azerbaijan'}, 'count': 171},
#  {'_id': {'country': 'Portugal'}, 'count': 171},
#  {'_id': {'country': 'Malawi'}, 'count': 171},
#  {'_id': {'country': 'Mali'}, 'count': 171},
#  {'_id': {'country': 'Cyprus'}, 'count': 171},
#  {'_id': {'country': 'India'}, 'count': 171},
#  {'_id': {'country': 'Israel'}, 'count': 171},
#  {'_id': {'country': 'Slovakia'}, 'count': 171},
#  {'_id': {'country': 'Sweden'}, 'count': 171},
#  {'_id': {'country': 'Kyrgyzstan'}, 'count': 171},
#  {'_id': {'country': 'Central African Republic'}, 'count': 171},
#  {'_id': {'country': 'Kosovo'}, 'count': 171},
#  {'_id': {'country': 'Ukraine'}, 'count': 171},
#  {'_id': {'country': 'Jordan'}, 'count': 171},
#  {'_id': {'country': 'Equatorial Guinea'}, 'count': 171},
#  {'_id': {'country': 'Liberia'}, 'count': 171},
#  {'_id': {'country': 'Bahamas'}, 'count': 171},
#  {'_id': {'country': 'Switzerland'}, 'count': 171}]

# %%
# давайте найдем все, которые были замеряны не 171 раз
# для этого добавим стадию match. она работает также как и обычный запрос в find
# но применяется уже к результату предыдущией стадии

"""
SELECT count(1) as count, country
FROM world
GROUP BY country
HAVING count <> 171
"""

p(world.aggregate([{'$group': {"_id": {"country": "$country"},
                               "count": {"$sum": 1}}},
                   {'$match': {"count" : {"$ne": 171}}}]))
# Out:
# [{'_id': {'country': 'Australia'}, 'count': 1368},
#  {'_id': {'country': 'United Kingdom'}, 'count': 1881},
#  {'_id': {'country': 'Denmark'}, 'count': 513},
#  {'_id': {'country': 'Canada'}, 'count': 2565},
#  {'_id': {'country': 'France'}, 'count': 1881},
#  {'_id': {'country': 'Netherlands'}, 'count': 855},
#  {'_id': {'country': 'China'}, 'count': 5643}]

# %%
# дополнительно можем отсортировать результаты
# таким образом, мы может добавлять произвольное количество стадий для сложной обрабоки

"""
SELECT count(1) as count, country
FROM world
GROUP BY country
HAVING count <> 171
ORDER BY count DESC
"""

p(world.aggregate([{"$group": {"_id": {"country": "$country"},
                               "count": {"$sum": 1}}},
                   {"$match": {"count" : {"$ne": 171}}},
                   {"$sort": {"count": -1}}])) # -1 - в порядке убывания, 1 - в порядке возрастания
# Out:
# [{'_id': {'country': 'China'}, 'count': 5643},
#  {'_id': {'country': 'Canada'}, 'count': 2565},
#  {'_id': {'country': 'United Kingdom'}, 'count': 1881},
#  {'_id': {'country': 'France'}, 'count': 1881},
#  {'_id': {'country': 'Australia'}, 'count': 1368},
#  {'_id': {'country': 'Netherlands'}, 'count': 855},
#  {'_id': {'country': 'Denmark'}, 'count': 513}]

# %%
# чтобы подсчитать глобальную статистику, можно использовать group, указав _id = None.
# тогда группировка произойдет как бы фиктивно, с использованием ровно одной группы — всей выборки
# например, подсчитаем среднее количество записей на страну и разброс

"""
SELECT avg(count), stddev_pop(count)
(SELECT sum(1) as count
 FROM world
 GROUP BY country) as r
"""

p(world.aggregate([{'$group': {"_id": {"country": "$country"},
                               "count": {"$sum": 1}}},
                   {'$group': {"_id": None,
                               "avg_count": {"$avg": "$count"},
                               "std_count": {"$stdDevPop": "$count"}}}]))
# Out:
# [{'_id': None, 'avg_count': 242.85638297872342, 'std_count': 475.8482969545827}]

# %%
# в базе данных есть страны с несколькими регионами, так что в один день может быть сразу несколько разных записей
# нам необходимо просуммировать все записи в регионах, чтобы узнать данные за день в конкретной стране

"""
SELECT country, date, sum(recovered), sum(confirmed), sum(deaths)
FROM world
GROUP BY (country, date)
LIMIT 20
"""

p(world.aggregate([{'$group': {"_id": {"country": "$country",
                                       "date": "$date"},  # группируем сразу по двум полям
                               "recovered": {'$sum': "$recovered"},  # для каждой группы складыаем все показатели 
                               "confirmed": {'$sum': "$confirmed"},
                               "deaths": {"$sum": "$deaths"}}},
                   {"$limit": 20}]))  # в агрегационном пайплайне можно отдельно указывать лимитирующий оператор
# Out:
# [{'_id': {'country': 'Cabo Verde', 'date': datetime.datetime(2020, 7, 8, 0, 0)},
#   'confirmed': 1542,
#   'deaths': 18,
#   'recovered': 730},
#  {'_id': {'country': 'Denmark', 'date': datetime.datetime(2020, 3, 15, 0, 0)},
#   'confirmed': 875,
#   'deaths': 2,
#   'recovered': 1},
#  {'_id': {'country': 'Spain', 'date': datetime.datetime(2020, 6, 24, 0, 0)},
#   'confirmed': 247086,
#   'deaths': 28327,
#   'recovered': 150376},
#  {'_id': {'country': 'Venezuela', 'date': datetime.datetime(2020, 6, 28, 0, 0)},
#   'confirmed': 5297,
#   'deaths': 44,
#   'recovered': 1649},
#  {'_id': {'country': 'Senegal', 'date': datetime.datetime(2020, 6, 1, 0, 0)},
#   'confirmed': 3739,
#   'deaths': 42,
#   'recovered': 1858},
#  {'_id': {'country': 'Jamaica', 'date': datetime.datetime(2020, 6, 6, 0, 0)},
#   'confirmed': 596,
#   'deaths': 10,
#   'recovered': 404},
#  {'_id': {'country': 'Belize', 'date': datetime.datetime(2020, 2, 2, 0, 0)},
#   'confirmed': 0,
#   'deaths': 0,
#   'recovered': 0},
#  {'_id': {'country': 'Kyrgyzstan', 'date': datetime.datetime(2020, 6, 2, 0, 0)},
#   'confirmed': 1845,
#   'deaths': 17,
#   'recovered': 1219},
#  {'_id': {'country': 'Sudan', 'date': datetime.datetime(2020, 6, 14, 0, 0)},
#   'confirmed': 7220,
#   'deaths': 459,
#   'recovered': 2610},
#  {'_id': {'country': 'Sierra Leone',
#           'date': datetime.datetime(2020, 1, 25, 0, 0)},
#   'confirmed': 0,
#   'deaths': 0,
#   'recovered': 0},
#  {'_id': {'country': 'Indonesia', 'date': datetime.datetime(2020, 4, 10, 0, 0)},
#   'confirmed': 3512,
#   'deaths': 306,
#   'recovered': 282},
#  {'_id': {'country': 'Bolivia', 'date': datetime.datetime(2020, 5, 2, 0, 0)},
#   'confirmed': 1470,
#   'deaths': 71,
#   'recovered': 159},
#  {'_id': {'country': 'Panama', 'date': datetime.datetime(2020, 4, 1, 0, 0)},
#   'confirmed': 1181,
#   'deaths': 30,
#   'recovered': 9},
#  {'_id': {'country': 'Brazil', 'date': datetime.datetime(2020, 6, 23, 0, 0)},
#   'confirmed': 1145906,
#   'deaths': 52645,
#   'recovered': 627963},
#  {'_id': {'country': 'Argentina', 'date': datetime.datetime(2020, 4, 20, 0, 0)},
#   'confirmed': 2941,
#   'deaths': 136,
#   'recovered': 737},
#  {'_id': {'country': 'Kuwait', 'date': datetime.datetime(2020, 3, 27, 0, 0)},
#   'confirmed': 225,
#   'deaths': 0,
#   'recovered': 57},
#  {'_id': {'country': 'Uganda', 'date': datetime.datetime(2020, 4, 9, 0, 0)},
#   'confirmed': 53,
#   'deaths': 0,
#   'recovered': 0},
#  {'_id': {'country': 'Zambia', 'date': datetime.datetime(2020, 3, 21, 0, 0)},
#   'confirmed': 2,
#   'deaths': 0,
#   'recovered': 0},
#  {'_id': {'country': 'United Arab Emirates',
#           'date': datetime.datetime(2020, 3, 25, 0, 0)},
#   'confirmed': 333,
#   'deaths': 2,
#   'recovered': 52},
#  {'_id': {'country': 'Tanzania', 'date': datetime.datetime(2020, 2, 19, 0, 0)},
#   'confirmed': 0,
#   'deaths': 0,
#   'recovered': 0}]

# %%
# поля можно сравнивать не только с константами, но и с другими полями
# например, можно найти дни, когда умерших больше, чем выздоровевших
# для этого нужно использовать специальный оператор expr, при помощи которого указывать условия можно
# в более свободной форме.

# для нашего случая - $expr: { $lt: ["$field_1", "$field_2"] } == "WHERE field_1 < field_2":

"""
SELECT country, date, sum(recovered) as recovered, sum(confirmed) as confirmed, sum(deaths) as deaths
FROM world
GROUP BY (country, date)
WHERE recovered < deaths
LIMIT 20
"""

p(world.aggregate([{"$group": {"_id": {"country": "$country",
                                       "date": "$date"}, # группируем сразу по двум полям
                               "recovered": {'$sum': "$recovered"},
                               "confirmed": {"$sum": "$confirmed"},
                               "deaths": {"$sum": "$deaths"}}},
                   {"$match": {"$expr": {"$lt": ["$recovered", "$deaths"]}}},
                   {"$limit": 20}]))
# Out:
# [{'_id': {'country': 'Portugal', 'date': datetime.datetime(2020, 4, 13, 0, 0)},
#   'confirmed': 16934,
#   'deaths': 535,
#   'recovered': 277},
#  {'_id': {'country': 'MS Zaandam', 'date': datetime.datetime(2020, 6, 5, 0, 0)},
#   'confirmed': 9,
#   'deaths': 2,
#   'recovered': 0},
#  {'_id': {'country': 'Bolivia', 'date': datetime.datetime(2020, 4, 19, 0, 0)},
#   'confirmed': 520,
#   'deaths': 32,
#   'recovered': 31},
#  {'_id': {'country': 'Nicaragua', 'date': datetime.datetime(2020, 5, 16, 0, 0)},
#   'confirmed': 25,
#   'deaths': 8,
#   'recovered': 7},
#  {'_id': {'country': 'Mexico', 'date': datetime.datetime(2020, 4, 1, 0, 0)},
#   'confirmed': 1378,
#   'deaths': 37,
#   'recovered': 35},
#  {'_id': {'country': 'Sweden', 'date': datetime.datetime(2020, 3, 27, 0, 0)},
#   'confirmed': 3069,
#   'deaths': 105,
#   'recovered': 0},
#  {'_id': {'country': 'United Kingdom',
#           'date': datetime.datetime(2020, 3, 23, 0, 0)},
#   'confirmed': 12744,
#   'deaths': 360,
#   'recovered': 67},
#  {'_id': {'country': 'United Kingdom',
#           'date': datetime.datetime(2020, 6, 6, 0, 0)},
#   'confirmed': 264944,
#   'deaths': 40548,
#   'recovered': 1230},
#  {'_id': {'country': 'Montenegro', 'date': datetime.datetime(2020, 4, 6, 0, 0)},
#   'confirmed': 233,
#   'deaths': 2,
#   'recovered': 1},
#  {'_id': {'country': 'Morocco', 'date': datetime.datetime(2020, 3, 31, 0, 0)},
#   'confirmed': 617,
#   'deaths': 36,
#   'recovered': 24},
#  {'_id': {'country': 'Sudan', 'date': datetime.datetime(2020, 3, 29, 0, 0)},
#   'confirmed': 6,
#   'deaths': 1,
#   'recovered': 0},
#  {'_id': {'country': 'Haiti', 'date': datetime.datetime(2020, 6, 3, 0, 0)},
#   'confirmed': 2507,
#   'deaths': 48,
#   'recovered': 24},
#  {'_id': {'country': 'Guatemala', 'date': datetime.datetime(2020, 3, 24, 0, 0)},
#   'confirmed': 21,
#   'deaths': 1,
#   'recovered': 0},
#  {'_id': {'country': 'US', 'date': datetime.datetime(2020, 3, 4, 0, 0)},
#   'confirmed': 104,
#   'deaths': 11,
#   'recovered': 7},
#  {'_id': {'country': 'United Kingdom',
#           'date': datetime.datetime(2020, 4, 26, 0, 0)},
#   'confirmed': 158926,
#   'deaths': 24117,
#   'recovered': 778},
#  {'_id': {'country': 'US', 'date': datetime.datetime(2020, 3, 21, 0, 0)},
#   'confirmed': 25825,
#   'deaths': 456,
#   'recovered': 176},
#  {'_id': {'country': 'Haiti', 'date': datetime.datetime(2020, 6, 7, 0, 0)},
#   'confirmed': 3334,
#   'deaths': 51,
#   'recovered': 24},
#  {'_id': {'country': 'Sweden', 'date': datetime.datetime(2020, 5, 15, 0, 0)},
#   'confirmed': 29207,
#   'deaths': 3646,
#   'recovered': 0},
#  {'_id': {'country': 'Indonesia', 'date': datetime.datetime(2020, 3, 29, 0, 0)},
#   'confirmed': 1285,
#   'deaths': 114,
#   'recovered': 64},
#  {'_id': {'country': 'Zimbabwe', 'date': datetime.datetime(2020, 4, 5, 0, 0)},
#   'confirmed': 9,
#   'deaths': 1,
#   'recovered': 0}]

# %%
# нам доступны также и другие агрегирующие функции
# например, мы можем найти дни, где среднее количество больше определенной константы:

"""
SELECT avg(recovered) as avg_recovered
FROM (SELECT country, date, sum(recovered) as recovered
      FROM world
      GROUP BY (country, date)) as r
GROUP BY date
HAVING avg_recovered > 10000
LIMIT 10
"""

p(world.aggregate([{'$group': {"_id": {"country": "$country",
                                       "date": "$date"}, # важно вначале сгрупировать по странам, чтобы среднее по стране считалось честно
                               "recovered": {'$sum': "$recovered"}}},  # для каждой группы складыаем все показатели 
                   {"$group": {"_id": {"date": "$_id.date"}, # ВАЖНО: date лежит теперь внутри _id. Доступ к нему идет через точку
                               "avg_recovered": {"$avg": "$recovered"}}},
                   {"$match": {"avg_recovered": {"$gt": 10000}}},
                   {"$limit": 10}]))
# Out:
# [{'_id': {'date': datetime.datetime(2020, 6, 6, 0, 0)},
#   'avg_recovered': 16418.707446808512},
#  {'_id': {'date': datetime.datetime(2020, 7, 7, 0, 0)},
#   'avg_recovered': 34296.04255319149},
#  {'_id': {'date': datetime.datetime(2020, 6, 24, 0, 0)},
#   'avg_recovered': 25245.308510638297},
#  {'_id': {'date': datetime.datetime(2020, 6, 10, 0, 0)},
#   'avg_recovered': 18376.632978723403},
#  {'_id': {'date': datetime.datetime(2020, 6, 17, 0, 0)},
#   'avg_recovered': 21669.97340425532},
#  {'_id': {'date': datetime.datetime(2020, 7, 10, 0, 0)},
#   'avg_recovered': 36593.19680851064},
#  {'_id': {'date': datetime.datetime(2020, 6, 4, 0, 0)},
#   'avg_recovered': 15666.803191489362},
#  {'_id': {'date': datetime.datetime(2020, 6, 28, 0, 0)},
#   'avg_recovered': 27345.207446808512},
#  {'_id': {'date': datetime.datetime(2020, 6, 3, 0, 0)},
#   'avg_recovered': 15294.308510638299},
#  {'_id': {'date': datetime.datetime(2020, 6, 5, 0, 0)},
#   'avg_recovered': 16034.654255319148}]
